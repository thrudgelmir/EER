# %% [markdown]
# Implementing **MTL** model for *Affect* and *User Recognition*

# %%
#from google.colab import files
import _pickle as pickle

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
import tensorflow as tf

from keras.layers import Input, Dense,Dropout,BatchNormalization,concatenate
from keras.models import Model
from keras import optimizers
from tensorflow.keras.utils import plot_model
# Out:
# 2025-07-20 12:27:00.974785: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-20 12:27:01.017533: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %% [markdown]
# ### Model Specification

# %%
def MTL_model(input_shapes_arr, num_classes_arr, label_names_arr):
  """   
    Building the architecture of the MTL model

    Parameters:
      input_shapes_arr (list): list of tuples containing the shape of the training set
      num_classes_arr  (list): list of int representing the layer size for the final output of the model,
                               AR task is a binary classification (stress vs no-stress)
                               UR task will need to distinguish between the subjects ID in the WESAD dataset
      label_names_arr  (list): list of str representing the output layer labels

      Both num_classes_arr and label_names_arr need to be sharing the same logical order, if the first element of
      num_classes_arr refers to the AR taks output layer size, then the first element of label_names_arr will also
      need to be the label of the AR task

    Returns:
      keras.engine.functional.Functional model instance
  """
  # List will contain the input layers
  inputs = []
  # Setting the dropout rate for the dropout layers
  dropout_rate = .0
  # Setting the learning rate for the optimizer
  learning_rate_opt = 0.001

  # Creating the two separate input layers for their respective task
  for input_shape in input_shapes_arr:
    x = Input(shape=input_shape)
    inputs.append(x)


  # Adding intermediate dense layers for balancing data dimensionality between the two task
  dense_reshape = Dense(100, activation='relu', name='intermediate_balancer')
  x_intermediate = dense_reshape(inputs[0])
  # Adding a batch normalization layer before the dropout layer
  batch = BatchNormalization() (x_intermediate)

  # Adding intermediate dense layers for balancing data dimensionality between the two task
  dense_reshape_2 = Dense(100, activation='relu', name='intermediate_balancer_2')
  x_intermediate_2 = dense_reshape_2(inputs[1])
  # Adding a batch normalization layer before the dropout layer
  batch_2 = BatchNormalization() (x_intermediate_2)

  # Adding dropout layers with the previously declared rate value
  dropout = Dropout(dropout_rate) (batch)
  dropout_2 = Dropout(dropout_rate) (batch_2)

  # Adding the shared layer to share knowledge between AR and UR
  dense_1 = Dense(20, activation='relu',name='shared_layer')
  # Linking the shared layer to the previously created dropout layers
  x1 = dense_1(dropout)
  x2 =  dense_1(dropout_2)

  # Output layer for AR task
  output_1 = Dense(num_classes_arr[0], activation="softmax",name = label_names_arr[0]) (x1)
  loss_1 = 'sparse_categorical_crossentropy'

  # Output layer for UR task
  output_2 = Dense(num_classes_arr[1], activation="softmax",name = label_names_arr[1]) (x2)
  loss_2 = 'sparse_categorical_crossentropy'

  # Creating the model
  model = Model(inputs=inputs, outputs=[output_1,output_2])
  # Setting the model optimizer
  optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate_opt)

  # Compiling the model
  model.compile(optimizer=optimizer, loss=[loss_1,loss_2], metrics=['accuracy'])

  return model

# %% [markdown]
# Model Visualization

# %%
# Instancing an example MTL model for architectural visualization
input_shape_1 = (2063,)
input_shape_2 = (2063,)
input_shapes = [input_shape_1,input_shape_2]
num_classes_arr = [2,18]
label_names_arr= ['AR','UR']

model = MTL_model(input_shapes,num_classes_arr,label_names_arr)
plot_model(model)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.
# 2025-07-20 12:27:01.764873: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-07-20 12:27:01.784190: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-07-20 12:27:01.785185: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-07-20 12:27:01.786377: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-20 12:27:01.787256: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-07-20 12:27:01.788184: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-07-20 12:27:01.789100: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-07-20 12:27:01.884016: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-07-20 12:27:01.885001: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-07-20 12:27:01.885934: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-07-20 12:27:01.886794: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22138 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %% [markdown]
# ### Pipeline Construction

# %%
def load_entire_dataset(window_size):
  """   
    Loading the dataset for the AR task with LOSO experimental setup

    Parameters:
      window_size (int) : window size in seconds, two variants have been developed
                          with 30 and 60 seconds window size support

    Returns:
      DataFrame df      : the dataframe representing the dataset for the specified 
                          window size
  """
  path_to_data = f"Stress_NoStress_dataset_{window_size}_sec_window.csv"
  df = pd.read_csv(path_to_data, index_col=0)

  return df

# %%
def load_contextual_datasets(window_size):
  """   
    Loading the dataset for the UR task with Start/End experimental setup

    Parameters:
      window_size (int) : window size in seconds, two variants have been developed
                          with 30 and 60 seconds window size support

    Returns:
      DataFrame df               : dataframe for Stress/No-Stress AR task
      list[DataFrame, DataFrame] : list of dataframe(s), containing the 5 minutes 
                                    Start/End split and the 3 minutes variant
      DataFrame df               : dataframe for the final minutes collected for the
                                   Start/End split procedure
  """
  print(f"Working on dataset with Window Size = {window_size} seconds.")

  # List that will contain the DataFrame for the collection of the initial minutes
  # of the Start/End split. It will be populated as [ 5 minutes Start split ; 3 minutes Start split]
  first_minutes_datasets = []
  first_minutes_datasets.append(pd.read_csv(f"{window_size}_sec_window_data_first_5_min.csv", index_col=0))
  first_minutes_datasets.append(pd.read_csv(f"{window_size}_sec_window_data_first_3_min.csv", index_col=0))

  # Reading the last minutes for the End split part of the Start/End split experimental setup
  unified_last_minutes = pd.read_csv(f"{window_size}_sec_window_data_last.csv", index_col=0)
  
  return load_entire_dataset(window_size), first_minutes_datasets, unified_last_minutes

# %%
def get_features_to_normalize():
  """   
    Features that will be normalized, expressed as column names

    Returns:
      list : column names of the features that will be normalized
  """
  features_to_normalize = ['median_p', 'mean_p', 'std_p', 'var_p', 'slope_p',
       'min_p', 'max_p', 'fdmean_p', 'fdstd_p', 'sdmean_p', 'sdstd_p',
       'drange_p', 'peaks_p', 'rise_time_p', 'max_deriv_p', 'amp_p',
       'decay_time_p', 'SCR_width_p', 'auc_p', 'median_t', 'mean_t', 'std_t',
       'var_t', 'slope_t', 'min_t', 'max_t', 'fdmean_t', 'fdstd_t', 'sdmean_t',
       'sdstd_t', 'drange_t', 'median_f', 'mean_f', 'std_f', 'var_f',
       'slope_f', 'min_f', 'max_f', 'fdmean_f', 'fdstd_f', 'sdmean_f',
       'sdstd_f', 'drange_f', 'peaks_f', 'rise_time_f', 'max_deriv_f', 'amp_f',
       'decay_time_f', 'SCR_width_f', 'auc_f', 'bpm', 'ibi', 'sdnn', 'sdsd',
       'rmssd', 'pnn20', 'pnn50', 'hr_mad', 'sd1', 'sd2', 's', 'sd1/sd2',
       'breathingrate', 'lf', 'hf', 'lf/hf', 'median_bvp', 'mean_bvp',
       'std_bvp', 'var_bvp', 'min_bvp', 'max_bvp', 'fdmean_bvp', 'fdstd_bvp',
       'sdmean_bvp', 'sdstd_bvp', 'drange_bvp']
       
  return features_to_normalize

# %%
def normalizing_data(df):
  """   
    Min-Max Normalization procedure

    Parameters:
      df (DataFrame)    : dataframe on which to perform the Min-Max normalization

    Returns:
      DataFrame df_norm : normalized dataframe
  """
  # Retrieve features that need to be normalized
  # as column items
  features_to_normalize = get_features_to_normalize()
  # Duplicate the dataframe received
  df_norm = df.copy()
 
  # Loop through the features that need to be normalized
  for feature in features_to_normalize:
    # Take the values
    values = df_norm[feature].copy()
    # Calculate the 1-st percentile
    minn = values.quantile(0.01)
    # Calculate the 99-th percentile
    maxx = values.quantile(0.99)
 
    # Winsorization, limiting extreme values for Min-Max
    values[values > maxx] = maxx
    values[values < minn] = minn
 
    # Avoid devision with 0
    if maxx != minn: 
      values = (values-minn)/(maxx-minn)
    else:
      values=0
    # Replace the original features values with the normalized ones  
    df_norm[feature] = values
 
  return df_norm

# %% [markdown]
# #### AR Task

# %%
from sklearn.metrics import accuracy_score
import numpy as np
def run_AR_task(df_norm, debug):
  eval_arr_task_1 = []
  from MLPLogistic import MLPLogistic
  accs = []
  for sub in df_norm.subjectID.unique():

    print('====== Test subject:', sub)

    # Training subset
    train_df = df_norm[df_norm.subjectID!=sub]
    # Test subset, testing the generalization of the model
    # on previously unseen subject data
    test_df = df_norm[df_norm.subjectID==sub]

    # Retrieve list of features that need to be normalized
    features_to_normalize = get_features_to_normalize()

    # Stress Recognition task
    train_X_1 = train_df[features_to_normalize].values
    # Labels will be the stress/no-stress labels
    train_y_1 = train_df['Label'].values
    model = MLPLogistic(train_X_1.shape[1], 32, 3000, 5e-2)
    model.fit(train_X_1,train_y_1)

    test_X_1 = test_df[features_to_normalize].values
    test_y_1 = test_df['Label'].values

    proba = model.forward(test_X_1)
    pred = np.where(proba>=0.5,1,0)
    accs.append(accuracy_score(test_y_1,pred))

    # User Recognition task
    train_X_2 = train_df[features_to_normalize].values
    # In this case the labels will be the IDs of the subjects
    train_y_2 = train_df['subjectID'].values

    test_X_2 = test_df[features_to_normalize].values
    test_y_2 = test_df['subjectID'].values

    # Preparing the model input parameters
    input_shape_1 = (train_X_1.shape[1],)
    input_shape_2 = (train_X_2.shape[1],)
    input_shapes = [input_shape_1,input_shape_2]
    num_classes_arr = [2,18]                 
    label_names_arr= ['Stress','UID']

    # Creating the input arrays for both training and testing
    train_X = [train_X_1,train_X_2]
    train_y = [train_y_1,train_y_2]
    test_X = [test_X_1,test_X_2]
    test_y = [test_y_1,test_y_2]
    # Unify the test arrays into a single validation tuple for model fitting
    validation_data = (test_X,test_y)

    # Instancing the model
    model = MTL_model(input_shapes,num_classes_arr,label_names_arr)

    # Fit the model with batch size of 15 and fixed epochs of 50
    h = model.fit(train_X,train_y,
                  shuffle=True,
                  batch_size=15,
                  validation_data = validation_data,
                  epochs=50, verbose=debug)
    
    # Appending learning history and evaluation figures
    eval_arr_task_1.append(model.evaluate(test_X,test_y))

  return accs, eval_arr_task_1

# %% [markdown]
# #### UR Task

# %% [markdown]
# #### Pipeline Execution

# %%
def run_pipeline(window_size, debug=0):
  """   
    Entire MTL model pipeline execution

    Parameters:
      window_size (int) : window size in seconds, two variants have been developed
                          with 30 and 60 seconds window size support
      debug (int)       : model fit verbosity, 0 = silent, 1 = progress bar

    Returns:
      model learning history, evaluation results for AR and UR
  """
  # Loading the datasets for the specified window_size variant
  df, first_minutes, unified_last_minutes = load_contextual_datasets(window_size)
  # Min-Max Normalization procedure
  df_norm = normalizing_data(df)

  print("Running AR task")
  # Executing the AR task with LOSO experimental setup
  return run_AR_task(df_norm, debug)

# %% [markdown]
# ### Plotting Model Results

# %% [markdown]
# ### Launch Pipeline

# %%
# Show all the pipelines output with 1, 0 otherwise
DEBUG = 0
# 60 seconds window size variant
ours_60,ours_30,mtl_60,mtl_30 = [],[],[],[]
for i in range(5) :
    a1_60, a2_60 = run_pipeline(60, debug=0)
    ours_60.append(a1_60)
    mtl_60.append(a2_60)
#a1_60, a2_60 = run_pipeline(60, debug=0)
# 30 seconds window size variant
    a1_30, a2_30 = run_pipeline(30, debug=0)
    ours_30.append(a1_30)
    mtl_30.append(a2_30)
# Out:
# Working on dataset with Window Size = 60 seconds.
# Running AR task
# ====== Test subject: 5
# 2025-07-20 12:27:04.737382: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2025-07-20 12:27:04.748828: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f3035d8b6d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-07-20 12:27:04.748849: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-07-20 12:27:04.753132: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-07-20 12:27:04.813764: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 5/5 [==============================] - 0s 2ms/step - loss: 20.9001 - Stress_loss: 0.0530 - UID_loss: 20.8470 - Stress_accuracy: 0.9865 - UID_accuracy: 0.0000e+00
# ====== Test subject: 2
# 5/5 [==============================] - 0s 1ms/step - loss: 23.4787 - Stress_loss: 0.2163 - UID_loss: 23.2624 - Stress_accuracy: 0.9574 - UID_accuracy: 0.0000e+00
# ====== Test subject: 3
# 5/5 [==============================] - 0s 2ms/step - loss: 26.4016 - Stress_loss: 0.5272 - UID_loss: 25.8745 - Stress_accuracy: 0.8472 - UID_accuracy: 0.0000e+00
# ====== Test subject: 4
# 5/5 [==============================] - 0s 2ms/step - loss: 26.6872 - Stress_loss: 0.0028 - UID_loss: 26.6844 - Stress_accuracy: 1.0000 - UID_accuracy: 0.0000e+00
# ====== Test subject: 17
# 5/5 [==============================] - 0s 2ms/step - loss: 21.0098 - Stress_loss: 1.1493 - UID_loss: 19.8605 - Stress_accuracy: 0.6733 - UID_accuracy: 0.0000e+00
# ====== Test subject: 10
# 5/5 [==============================] - 0s 2ms/step - loss: 21.4454 - Stress_loss: 0.0010 - UID_loss: 21.4444 - Stress_accuracy: 1.0000 - UID_accuracy: 0.0000e+00
# ====== Test subject: 11
# 5/5 [==============================] - 0s 2ms/step - loss: 17.9127 - Stress_loss: 0.3333 - UID_loss: 17.5795 - Stress_accuracy: 0.9664 - UID_accuracy: 0.0000e+00
# ====== Test subject: 16
# 5/5 [==============================] - 0s 1ms/step - loss: 21.7998 - Stress_loss: 0.0062 - UID_loss: 21.7935 - Stress_accuracy: 1.0000 - UID_accuracy: 0.0000e+00
# ====== Test subject: 8
# 5/5 [==============================] - 0s 1ms/step - loss: 18.8057 - Stress_loss: 0.0061 - UID_loss: 18.7996 - Stress_accuracy: 1.0000 - UID_accuracy: 0.0000e+00
# ====== Test subject: 6
# 5/5 [==============================] - 0s 2ms/step - loss: 24.4344 - Stress_loss: 0.0226 - UID_loss: 24.4118 - Stress_accuracy: 0.9864 - UID_accuracy: 0.0000e+00
# ====== Test subject: 7
# 5/5 [==============================] - 0s 1ms/step - loss: 30.3742 - Stress_loss: 0.3325 - UID_loss: 30.0416 - Stress_accuracy: 0.8844 - UID_accuracy: 0.0000e+00
# ====== Test subject: 9
# 5/5 [==============================] - 0s 1ms/step - loss: 20.6433 - Stress_loss: 0.0264 - UID_loss: 20.6169 - Stress_accuracy: 0.9932 - UID_accuracy: 0.0000e+00
# ====== Test subject: 13
# 5/5 [==============================] - 0s 1ms/step - loss: 32.6398 - Stress_loss: 0.1836 - UID_loss: 32.4563 - Stress_accuracy: 0.9530 - UID_accuracy: 0.0000e+00
# ====== Test subject: 14
# 5/5 [==============================] - 0s 1ms/step - loss: 50.1761 - Stress_loss: 1.5479 - UID_loss: 48.6283 - Stress_accuracy: 0.5772 - UID_accuracy: 0.0000e+00
# ====== Test subject: 15
# 5/5 [==============================] - 0s 1ms/step - loss: 20.1138 - Stress_loss: 0.3124 - UID_loss: 19.8014 - Stress_accuracy: 0.9262 - UID_accuracy: 0.0000e+00
# Working on dataset with Window Size = 30 seconds.
# Running AR task
# ====== Test subject: 5
# 10/10 [==============================] - 0s 1ms/step - loss: 25.5142 - Stress_loss: 0.0504 - UID_loss: 25.4638 - Stress_accuracy: 0.9797 - UID_accuracy: 0.0000e+00
# ====== Test subject: 2
# 9/9 [==============================] - 0s 1ms/step - loss: 28.6415 - Stress_loss: 0.4464 - UID_loss: 28.1951 - Stress_accuracy: 0.8975 - UID_accuracy: 0.0000e+00
# ====== Test subject: 3
# 9/9 [==============================] - 0s 1ms/step - loss: 30.0368 - Stress_loss: 1.0402 - UID_loss: 28.9966 - Stress_accuracy: 0.7979 - UID_accuracy: 0.0000e+00
# ====== Test subject: 4
# 9/9 [==============================] - 0s 1ms/step - loss: 32.4100 - Stress_loss: 0.0548 - UID_loss: 32.3552 - Stress_accuracy: 0.9826 - UID_accuracy: 0.0000e+00
# ====== Test subject: 17
# 10/10 [==============================] - 0s 1ms/step - loss: 28.0121 - Stress_loss: 1.3864 - UID_loss: 26.6257 - Stress_accuracy: 0.6821 - UID_accuracy: 0.0000e+00
# ====== Test subject: 10
# 10/10 [==============================] - 0s 1ms/step - loss: 19.5790 - Stress_loss: 0.3420 - UID_loss: 19.2370 - Stress_accuracy: 0.8684 - UID_accuracy: 0.0000e+00
# ====== Test subject: 11
# 10/10 [==============================] - 0s 1ms/step - loss: 18.9339 - Stress_loss: 0.5566 - UID_loss: 18.3774 - Stress_accuracy: 0.8557 - UID_accuracy: 0.0000e+00
# ====== Test subject: 16
# 10/10 [==============================] - 0s 1ms/step - loss: 20.3969 - Stress_loss: 0.0345 - UID_loss: 20.3624 - Stress_accuracy: 0.9831 - UID_accuracy: 0.0000e+00
# ====== Test subject: 8
# 10/10 [==============================] - 0s 1ms/step - loss: 20.6386 - Stress_loss: 0.0152 - UID_loss: 20.6235 - Stress_accuracy: 0.9966 - UID_accuracy: 0.0000e+00
# ====== Test subject: 6
# 10/10 [==============================] - 0s 1ms/step - loss: 31.2084 - Stress_loss: 0.1252 - UID_loss: 31.0832 - Stress_accuracy: 0.9592 - UID_accuracy: 0.0000e+00
# ====== Test subject: 7
# 10/10 [==============================] - 0s 1ms/step - loss: 23.2792 - Stress_loss: 0.1376 - UID_loss: 23.1416 - Stress_accuracy: 0.9626 - UID_accuracy: 0.0000e+00
# ====== Test subject: 9
# 10/10 [==============================] - 0s 1ms/step - loss: 24.7409 - Stress_loss: 0.0465 - UID_loss: 24.6944 - Stress_accuracy: 0.9829 - UID_accuracy: 0.0000e+00
# ====== Test subject: 13
# 10/10 [==============================] - 0s 1ms/step - loss: 44.2917 - Stress_loss: 0.0919 - UID_loss: 44.1998 - Stress_accuracy: 0.9664 - UID_accuracy: 0.0000e+00
# ====== Test subject: 14
# 10/10 [==============================] - 0s 1ms/step - loss: 56.1782 - Stress_loss: 1.0813 - UID_loss: 55.0969 - Stress_accuracy: 0.7475 - UID_accuracy: 0.0000e+00
# ====== Test subject: 15
# 10/10 [==============================] - 0s 1ms/step - loss: 23.4280 - Stress_loss: 0.1777 - UID_loss: 23.2504 - Stress_accuracy: 0.9564 - UID_accuracy: 0.0000e+00
# Working on dataset with Window Size = 60 seconds.
# Running AR task
# ====== Test subject: 5
# 5/5 [==============================] - 0s 2ms/step - loss: 22.8571 - Stress_loss: 0.1459 - UID_loss: 22.7112 - Stress_accuracy: 0.9865 - UID_accuracy: 0.0000e+00
# ====== Test subject: 2
# 5/5 [==============================] - 0s 2ms/step - loss: 30.3127 - Stress_loss: 0.2776 - UID_loss: 30.0351 - Stress_accuracy: 0.9362 - UID_accuracy: 0.0000e+00
# ====== Test subject: 3
# 5/5 [==============================] - 0s 1ms/step - loss: 20.3728 - Stress_loss: 0.4864 - UID_loss: 19.8864 - Stress_accuracy: 0.9028 - UID_accuracy: 0.0000e+00
# ====== Test subject: 4
# 5/5 [==============================] - 0s 1ms/step - loss: 24.0112 - Stress_loss: 3.8098e-04 - UID_loss: 24.0108 - Stress_accuracy: 1.0000 - UID_accuracy: 0.0000e+00
# ====== Test subject: 17
# 5/5 [==============================] - 0s 2ms/step - loss: 21.6408 - Stress_loss: 1.4878 - UID_loss: 20.1530 - Stress_accuracy: 0.7267 - UID_accuracy: 0.0000e+00
# ====== Test subject: 10
# 5/5 [==============================] - 0s 2ms/step - loss: 17.4856 - Stress_loss: 0.0023 - UID_loss: 17.4834 - Stress_accuracy: 1.0000 - UID_accuracy: 0.0000e+00
# ====== Test subject: 11
# 5/5 [==============================] - 0s 2ms/step - loss: 23.7962 - Stress_loss: 0.4183 - UID_loss: 23.3779 - Stress_accuracy: 0.9128 - UID_accuracy: 0.0000e+00
# ====== Test subject: 16
# 5/5 [==============================] - 0s 1ms/step - loss: 21.2824 - Stress_loss: 0.0127 - UID_loss: 21.2697 - Stress_accuracy: 1.0000 - UID_accuracy: 0.0000e+00
# ====== Test subject: 8
# 5/5 [==============================] - 0s 1ms/step - loss: 19.9526 - Stress_loss: 0.0062 - UID_loss: 19.9464 - Stress_accuracy: 1.0000 - UID_accuracy: 0.0000e+00
# ====== Test subject: 6
# 5/5 [==============================] - 0s 1ms/step - loss: 22.0230 - Stress_loss: 0.0260 - UID_loss: 21.9970 - Stress_accuracy: 0.9932 - UID_accuracy: 0.0000e+00
# ====== Test subject: 7
# 5/5 [==============================] - 0s 1ms/step - loss: 22.1045 - Stress_loss: 0.2351 - UID_loss: 21.8694 - Stress_accuracy: 0.8776 - UID_accuracy: 0.0000e+00
# ====== Test subject: 9
# 5/5 [==============================] - 0s 2ms/step - loss: 18.1886 - Stress_loss: 0.0526 - UID_loss: 18.1360 - Stress_accuracy: 0.9863 - UID_accuracy: 0.0000e+00
# ====== Test subject: 13
# 5/5 [==============================] - 0s 1ms/step - loss: 33.3331 - Stress_loss: 0.2172 - UID_loss: 33.1160 - Stress_accuracy: 0.9664 - UID_accuracy: 0.0000e+00
# ====== Test subject: 14
# 5/5 [==============================] - 0s 1ms/step - loss: 51.8617 - Stress_loss: 3.0841 - UID_loss: 48.7776 - Stress_accuracy: 0.6174 - UID_accuracy: 0.0000e+00
# ====== Test subject: 15
# 5/5 [==============================] - 0s 1ms/step - loss: 21.2608 - Stress_loss: 0.1182 - UID_loss: 21.1427 - Stress_accuracy: 0.9597 - UID_accuracy: 0.0000e+00
# Working on dataset with Window Size = 30 seconds.
# Running AR task
# ====== Test subject: 5
# 10/10 [==============================] - 0s 2ms/step - loss: 18.5388 - Stress_loss: 0.1200 - UID_loss: 18.4188 - Stress_accuracy: 0.9492 - UID_accuracy: 0.0000e+00
# ====== Test subject: 2
# 9/9 [==============================] - 0s 1ms/step - loss: 31.5934 - Stress_loss: 0.2003 - UID_loss: 31.3931 - Stress_accuracy: 0.9329 - UID_accuracy: 0.0000e+00
# ====== Test subject: 3
# 9/9 [==============================] - 0s 1ms/step - loss: 25.6798 - Stress_loss: 1.4039 - UID_loss: 24.2759 - Stress_accuracy: 0.8014 - UID_accuracy: 0.0000e+00
# ====== Test subject: 4
# 9/9 [==============================] - 0s 1ms/step - loss: 28.3854 - Stress_loss: 0.0288 - UID_loss: 28.3566 - Stress_accuracy: 0.9931 - UID_accuracy: 0.0000e+00
# ====== Test subject: 17
# 10/10 [==============================] - 0s 1ms/step - loss: 25.8607 - Stress_loss: 1.9334 - UID_loss: 23.9273 - Stress_accuracy: 0.5397 - UID_accuracy: 0.0000e+00
# ====== Test subject: 10
# 10/10 [==============================] - 0s 1ms/step - loss: 20.2641 - Stress_loss: 0.2110 - UID_loss: 20.0531 - Stress_accuracy: 0.9178 - UID_accuracy: 0.0000e+00
# ====== Test subject: 11
# 10/10 [==============================] - 0s 1ms/step - loss: 21.4653 - Stress_loss: 0.6537 - UID_loss: 20.8116 - Stress_accuracy: 0.8456 - UID_accuracy: 0.0000e+00
# ====== Test subject: 16
# 10/10 [==============================] - 0s 1ms/step - loss: 23.7678 - Stress_loss: 0.1019 - UID_loss: 23.6659 - Stress_accuracy: 0.9661 - UID_accuracy: 0.0000e+00
# ====== Test subject: 8
# 10/10 [==============================] - 0s 2ms/step - loss: 32.0176 - Stress_loss: 0.0602 - UID_loss: 31.9574 - Stress_accuracy: 0.9763 - UID_accuracy: 0.0000e+00
# ====== Test subject: 6
# 10/10 [==============================] - 0s 1ms/step - loss: 29.5362 - Stress_loss: 0.0992 - UID_loss: 29.4371 - Stress_accuracy: 0.9626 - UID_accuracy: 0.0000e+00
# ====== Test subject: 7
# 10/10 [==============================] - 0s 1ms/step - loss: 26.3164 - Stress_loss: 0.0659 - UID_loss: 26.2505 - Stress_accuracy: 0.9762 - UID_accuracy: 0.0000e+00
# ====== Test subject: 9
# 10/10 [==============================] - 0s 1ms/step - loss: 27.4513 - Stress_loss: 0.0418 - UID_loss: 27.4096 - Stress_accuracy: 0.9829 - UID_accuracy: 0.0000e+00
# ====== Test subject: 13
# 10/10 [==============================] - 0s 1ms/step - loss: 47.6422 - Stress_loss: 0.0614 - UID_loss: 47.5808 - Stress_accuracy: 0.9799 - UID_accuracy: 0.0000e+00
# ====== Test subject: 14
# 10/10 [==============================] - 0s 1ms/step - loss: 37.8315 - Stress_loss: 1.3924 - UID_loss: 36.4391 - Stress_accuracy: 0.7037 - UID_accuracy: 0.0000e+00
# ====== Test subject: 15
# 10/10 [==============================] - 0s 1ms/step - loss: 28.1303 - Stress_loss: 0.1452 - UID_loss: 27.9850 - Stress_accuracy: 0.9664 - UID_accuracy: 0.0000e+00
# Working on dataset with Window Size = 60 seconds.
# Running AR task
# ====== Test subject: 5
# 5/5 [==============================] - 0s 1ms/step - loss: 19.3556 - Stress_loss: 0.2221 - UID_loss: 19.1335 - Stress_accuracy: 0.9392 - UID_accuracy: 0.0000e+00
# ====== Test subject: 2
# 5/5 [==============================] - 0s 2ms/step - loss: 24.1550 - Stress_loss: 0.1618 - UID_loss: 23.9933 - Stress_accuracy: 0.9645 - UID_accuracy: 0.0000e+00
# ====== Test subject: 3
# 5/5 [==============================] - 0s 2ms/step - loss: 26.1870 - Stress_loss: 0.3057 - UID_loss: 25.8813 - Stress_accuracy: 0.8889 - UID_accuracy: 0.0000e+00
# ====== Test subject: 4
# 5/5 [==============================] - 0s 1ms/step - loss: 24.0579 - Stress_loss: 0.0070 - UID_loss: 24.0509 - Stress_accuracy: 1.0000 - UID_accuracy: 0.0000e+00
# ====== Test subject: 17
# 5/5 [==============================] - 0s 2ms/step - loss: 18.4513 - Stress_loss: 0.9793 - UID_loss: 17.4720 - Stress_accuracy: 0.7133 - UID_accuracy: 0.0000e+00
# ====== Test subject: 10
# 5/5 [==============================] - 0s 1ms/step - loss: 19.0997 - Stress_loss: 0.0994 - UID_loss: 19.0003 - Stress_accuracy: 0.9671 - UID_accuracy: 0.0000e+00
# ====== Test subject: 11
# 5/5 [==============================] - 0s 1ms/step - loss: 21.7856 - Stress_loss: 0.7098 - UID_loss: 21.0758 - Stress_accuracy: 0.9329 - UID_accuracy: 0.0000e+00
# ====== Test subject: 16
# 5/5 [==============================] - 0s 2ms/step - loss: 15.9073 - Stress_loss: 0.0101 - UID_loss: 15.8971 - Stress_accuracy: 1.0000 - UID_accuracy: 0.0000e+00
# ====== Test subject: 8
# 5/5 [==============================] - 0s 1ms/step - loss: 29.4566 - Stress_loss: 0.0022 - UID_loss: 29.4544 - Stress_accuracy: 1.0000 - UID_accuracy: 0.0000e+00
# ====== Test subject: 6
# 5/5 [==============================] - 0s 1ms/step - loss: 24.1508 - Stress_loss: 0.0427 - UID_loss: 24.1081 - Stress_accuracy: 0.9796 - UID_accuracy: 0.0000e+00
# ====== Test subject: 7
# 5/5 [==============================] - 0s 1ms/step - loss: 26.0560 - Stress_loss: 0.0407 - UID_loss: 26.0153 - Stress_accuracy: 0.9796 - UID_accuracy: 0.0000e+00
# ====== Test subject: 9
# 5/5 [==============================] - 0s 2ms/step - loss: 22.2679 - Stress_loss: 0.0855 - UID_loss: 22.1824 - Stress_accuracy: 0.9863 - UID_accuracy: 0.0000e+00
# ====== Test subject: 13
# 5/5 [==============================] - 0s 1ms/step - loss: 37.6880 - Stress_loss: 0.1758 - UID_loss: 37.5121 - Stress_accuracy: 0.9664 - UID_accuracy: 0.0000e+00
# ====== Test subject: 14
# 5/5 [==============================] - 0s 1ms/step - loss: 51.3762 - Stress_loss: 1.5045 - UID_loss: 49.8717 - Stress_accuracy: 0.6510 - UID_accuracy: 0.0000e+00
# ====== Test subject: 15
# 5/5 [==============================] - 0s 1ms/step - loss: 21.4998 - Stress_loss: 0.2009 - UID_loss: 21.2989 - Stress_accuracy: 0.9597 - UID_accuracy: 0.0000e+00
# Working on dataset with Window Size = 30 seconds.
# Running AR task
# ====== Test subject: 5
# 10/10 [==============================] - 0s 1ms/step - loss: 19.5829 - Stress_loss: 0.1471 - UID_loss: 19.4358 - Stress_accuracy: 0.9661 - UID_accuracy: 0.0000e+00
# ====== Test subject: 2
# 9/9 [==============================] - 0s 1ms/step - loss: 24.5405 - Stress_loss: 0.1734 - UID_loss: 24.3671 - Stress_accuracy: 0.9329 - UID_accuracy: 0.0000e+00
# ====== Test subject: 3
# 9/9 [==============================] - 0s 1ms/step - loss: 25.9774 - Stress_loss: 0.9652 - UID_loss: 25.0122 - Stress_accuracy: 0.8153 - UID_accuracy: 0.0000e+00
# ====== Test subject: 4
# 9/9 [==============================] - 0s 1ms/step - loss: 37.3721 - Stress_loss: 0.0112 - UID_loss: 37.3610 - Stress_accuracy: 0.9965 - UID_accuracy: 0.0000e+00
# ====== Test subject: 17
# 10/10 [==============================] - 0s 1ms/step - loss: 25.9637 - Stress_loss: 1.2909 - UID_loss: 24.6728 - Stress_accuracy: 0.6623 - UID_accuracy: 0.0000e+00
# ====== Test subject: 10
# 10/10 [==============================] - 0s 1ms/step - loss: 18.3540 - Stress_loss: 0.0817 - UID_loss: 18.2723 - Stress_accuracy: 0.9803 - UID_accuracy: 0.0000e+00
# ====== Test subject: 11
# 10/10 [==============================] - 0s 1ms/step - loss: 21.6268 - Stress_loss: 0.5993 - UID_loss: 21.0275 - Stress_accuracy: 0.8054 - UID_accuracy: 0.0000e+00
# ====== Test subject: 16
# 10/10 [==============================] - 0s 1ms/step - loss: 24.2975 - Stress_loss: 0.0254 - UID_loss: 24.2721 - Stress_accuracy: 0.9932 - UID_accuracy: 0.0000e+00
# ====== Test subject: 8
# 10/10 [==============================] - 0s 1ms/step - loss: 22.1964 - Stress_loss: 0.0455 - UID_loss: 22.1510 - Stress_accuracy: 0.9763 - UID_accuracy: 0.0000e+00
# ====== Test subject: 6
# 10/10 [==============================] - 0s 1ms/step - loss: 24.6671 - Stress_loss: 0.0232 - UID_loss: 24.6438 - Stress_accuracy: 0.9864 - UID_accuracy: 0.0000e+00
# ====== Test subject: 7
# 10/10 [==============================] - 0s 1ms/step - loss: 32.5419 - Stress_loss: 0.0690 - UID_loss: 32.4729 - Stress_accuracy: 0.9762 - UID_accuracy: 0.0000e+00
# ====== Test subject: 9
# 10/10 [==============================] - 0s 1ms/step - loss: 21.8669 - Stress_loss: 0.0135 - UID_loss: 21.8534 - Stress_accuracy: 0.9966 - UID_accuracy: 0.0000e+00
# ====== Test subject: 13
# 10/10 [==============================] - 0s 1ms/step - loss: 46.7852 - Stress_loss: 0.1293 - UID_loss: 46.6560 - Stress_accuracy: 0.9732 - UID_accuracy: 0.0000e+00
# ====== Test subject: 14
# 10/10 [==============================] - 0s 1ms/step - loss: 52.6255 - Stress_loss: 0.9662 - UID_loss: 51.6593 - Stress_accuracy: 0.7407 - UID_accuracy: 0.0000e+00
# ====== Test subject: 15
# 10/10 [==============================] - 0s 1ms/step - loss: 20.2714 - Stress_loss: 0.1468 - UID_loss: 20.1246 - Stress_accuracy: 0.9664 - UID_accuracy: 0.0000e+00
# Working on dataset with Window Size = 60 seconds.
# Running AR task
# ====== Test subject: 5
# 5/5 [==============================] - 0s 2ms/step - loss: 17.0360 - Stress_loss: 0.1348 - UID_loss: 16.9012 - Stress_accuracy: 0.9595 - UID_accuracy: 0.0000e+00
# ====== Test subject: 2
# 5/5 [==============================] - 0s 2ms/step - loss: 31.6649 - Stress_loss: 0.1632 - UID_loss: 31.5017 - Stress_accuracy: 0.9574 - UID_accuracy: 0.0000e+00
# ====== Test subject: 3
# 5/5 [==============================] - 0s 1ms/step - loss: 25.1081 - Stress_loss: 0.7227 - UID_loss: 24.3854 - Stress_accuracy: 0.8472 - UID_accuracy: 0.0000e+00
# ====== Test subject: 4
# 5/5 [==============================] - 0s 2ms/step - loss: 22.2097 - Stress_loss: 1.2186e-04 - UID_loss: 22.2096 - Stress_accuracy: 1.0000 - UID_accuracy: 0.0000e+00
# ====== Test subject: 17
# 5/5 [==============================] - 0s 2ms/step - loss: 22.0885 - Stress_loss: 1.5592 - UID_loss: 20.5293 - Stress_accuracy: 0.7267 - UID_accuracy: 0.0000e+00
# ====== Test subject: 10
# 5/5 [==============================] - 0s 1ms/step - loss: 16.2837 - Stress_loss: 0.0109 - UID_loss: 16.2729 - Stress_accuracy: 1.0000 - UID_accuracy: 0.0000e+00
# ====== Test subject: 11
# 5/5 [==============================] - 0s 1ms/step - loss: 19.3980 - Stress_loss: 0.6444 - UID_loss: 18.7536 - Stress_accuracy: 0.8926 - UID_accuracy: 0.0000e+00
# ====== Test subject: 16
# 5/5 [==============================] - 0s 1ms/step - loss: 20.5416 - Stress_loss: 0.1579 - UID_loss: 20.3837 - Stress_accuracy: 0.9527 - UID_accuracy: 0.0000e+00
# ====== Test subject: 8
# 5/5 [==============================] - 0s 2ms/step - loss: 17.9769 - Stress_loss: 0.0215 - UID_loss: 17.9554 - Stress_accuracy: 0.9865 - UID_accuracy: 0.0000e+00
# ====== Test subject: 6
# 5/5 [==============================] - 0s 2ms/step - loss: 22.0755 - Stress_loss: 0.0319 - UID_loss: 22.0435 - Stress_accuracy: 0.9932 - UID_accuracy: 0.0000e+00
# ====== Test subject: 7
# 5/5 [==============================] - 0s 1ms/step - loss: 24.4593 - Stress_loss: 0.1677 - UID_loss: 24.2916 - Stress_accuracy: 0.9456 - UID_accuracy: 0.0000e+00
# ====== Test subject: 9
# 5/5 [==============================] - 0s 1ms/step - loss: 21.3693 - Stress_loss: 0.1073 - UID_loss: 21.2620 - Stress_accuracy: 0.9795 - UID_accuracy: 0.0000e+00
# ====== Test subject: 13
# 5/5 [==============================] - 0s 1ms/step - loss: 35.4552 - Stress_loss: 0.0733 - UID_loss: 35.3819 - Stress_accuracy: 0.9732 - UID_accuracy: 0.0000e+00
# ====== Test subject: 14
# 5/5 [==============================] - 0s 1ms/step - loss: 45.2555 - Stress_loss: 2.6200 - UID_loss: 42.6356 - Stress_accuracy: 0.5302 - UID_accuracy: 0.0000e+00
# ====== Test subject: 15
# 5/5 [==============================] - 0s 1ms/step - loss: 24.9168 - Stress_loss: 0.0779 - UID_loss: 24.8388 - Stress_accuracy: 0.9732 - UID_accuracy: 0.0000e+00
# Working on dataset with Window Size = 30 seconds.
# Running AR task
# ====== Test subject: 5
# 10/10 [==============================] - 0s 1ms/step - loss: 20.9281 - Stress_loss: 0.2480 - UID_loss: 20.6801 - Stress_accuracy: 0.9220 - UID_accuracy: 0.0000e+00
# ====== Test subject: 2
# 9/9 [==============================] - 0s 1ms/step - loss: 24.7643 - Stress_loss: 0.2775 - UID_loss: 24.4868 - Stress_accuracy: 0.9046 - UID_accuracy: 0.0000e+00
# ====== Test subject: 3
# 9/9 [==============================] - 0s 1ms/step - loss: 28.3024 - Stress_loss: 0.6709 - UID_loss: 27.6314 - Stress_accuracy: 0.8397 - UID_accuracy: 0.0000e+00
# ====== Test subject: 4
# 9/9 [==============================] - 0s 1ms/step - loss: 38.3514 - Stress_loss: 0.0293 - UID_loss: 38.3221 - Stress_accuracy: 0.9896 - UID_accuracy: 0.0000e+00
# ====== Test subject: 17
# 10/10 [==============================] - 0s 1ms/step - loss: 23.8904 - Stress_loss: 2.3785 - UID_loss: 21.5119 - Stress_accuracy: 0.5629 - UID_accuracy: 0.0000e+00
# ====== Test subject: 10
# 10/10 [==============================] - 0s 1ms/step - loss: 24.8827 - Stress_loss: 0.0411 - UID_loss: 24.8417 - Stress_accuracy: 0.9868 - UID_accuracy: 0.0000e+00
# ====== Test subject: 11
# 10/10 [==============================] - 0s 1ms/step - loss: 19.9274 - Stress_loss: 0.2812 - UID_loss: 19.6461 - Stress_accuracy: 0.9228 - UID_accuracy: 0.0000e+00
# ====== Test subject: 16
# 10/10 [==============================] - 0s 1ms/step - loss: 19.4730 - Stress_loss: 0.0054 - UID_loss: 19.4676 - Stress_accuracy: 0.9966 - UID_accuracy: 0.0000e+00
# ====== Test subject: 8
# 10/10 [==============================] - 0s 1ms/step - loss: 35.4197 - Stress_loss: 0.0485 - UID_loss: 35.3712 - Stress_accuracy: 0.9797 - UID_accuracy: 0.0000e+00
# ====== Test subject: 6
# 10/10 [==============================] - 0s 1ms/step - loss: 31.2911 - Stress_loss: 0.0569 - UID_loss: 31.2343 - Stress_accuracy: 0.9728 - UID_accuracy: 0.0000e+00
# ====== Test subject: 7
# 10/10 [==============================] - 0s 1ms/step - loss: 32.3793 - Stress_loss: 0.1954 - UID_loss: 32.1839 - Stress_accuracy: 0.9184 - UID_accuracy: 0.0000e+00
# ====== Test subject: 9
# 10/10 [==============================] - 0s 1ms/step - loss: 24.1987 - Stress_loss: 0.0093 - UID_loss: 24.1894 - Stress_accuracy: 1.0000 - UID_accuracy: 0.0000e+00
# ====== Test subject: 13
# 10/10 [==============================] - 0s 1ms/step - loss: 34.0147 - Stress_loss: 0.1760 - UID_loss: 33.8387 - Stress_accuracy: 0.9631 - UID_accuracy: 0.0000e+00
# ====== Test subject: 14
# 10/10 [==============================] - 0s 1ms/step - loss: 53.5650 - Stress_loss: 1.7423 - UID_loss: 51.8227 - Stress_accuracy: 0.6263 - UID_accuracy: 0.0000e+00
# ====== Test subject: 15
# 10/10 [==============================] - 0s 1ms/step - loss: 21.2732 - Stress_loss: 0.1369 - UID_loss: 21.1363 - Stress_accuracy: 0.9698 - UID_accuracy: 0.0000e+00
# Working on dataset with Window Size = 60 seconds.
# Running AR task
# ====== Test subject: 5
# 5/5 [==============================] - 0s 2ms/step - loss: 17.5854 - Stress_loss: 0.0259 - UID_loss: 17.5595 - Stress_accuracy: 0.9932 - UID_accuracy: 0.0000e+00
# ====== Test subject: 2
# 5/5 [==============================] - 0s 2ms/step - loss: 26.6743 - Stress_loss: 0.2150 - UID_loss: 26.4593 - Stress_accuracy: 0.9716 - UID_accuracy: 0.0000e+00
# ====== Test subject: 3
# 5/5 [==============================] - 0s 1ms/step - loss: 23.5033 - Stress_loss: 0.7686 - UID_loss: 22.7347 - Stress_accuracy: 0.8542 - UID_accuracy: 0.0000e+00
# ====== Test subject: 4
# 5/5 [==============================] - 0s 2ms/step - loss: 19.6093 - Stress_loss: 0.0025 - UID_loss: 19.6068 - Stress_accuracy: 1.0000 - UID_accuracy: 0.0000e+00
# ====== Test subject: 17
# 5/5 [==============================] - 0s 2ms/step - loss: 22.1314 - Stress_loss: 3.3829 - UID_loss: 18.7485 - Stress_accuracy: 0.6267 - UID_accuracy: 0.0000e+00
# ====== Test subject: 10
# 5/5 [==============================] - 0s 1ms/step - loss: 17.0462 - Stress_loss: 0.0363 - UID_loss: 17.0098 - Stress_accuracy: 0.9868 - UID_accuracy: 0.0000e+00
# ====== Test subject: 11
# 5/5 [==============================] - 0s 1ms/step - loss: 18.6272 - Stress_loss: 0.4022 - UID_loss: 18.2250 - Stress_accuracy: 0.9128 - UID_accuracy: 0.0000e+00
# ====== Test subject: 16
# 5/5 [==============================] - 0s 2ms/step - loss: 17.3768 - Stress_loss: 0.0191 - UID_loss: 17.3576 - Stress_accuracy: 0.9932 - UID_accuracy: 0.0000e+00
# ====== Test subject: 8
# 5/5 [==============================] - 0s 1ms/step - loss: 23.3181 - Stress_loss: 0.0087 - UID_loss: 23.3094 - Stress_accuracy: 1.0000 - UID_accuracy: 0.0000e+00
# ====== Test subject: 6
# 5/5 [==============================] - 0s 1ms/step - loss: 21.1047 - Stress_loss: 0.1181 - UID_loss: 20.9866 - Stress_accuracy: 0.9524 - UID_accuracy: 0.0000e+00
# ====== Test subject: 7
# 5/5 [==============================] - 0s 2ms/step - loss: 26.4499 - Stress_loss: 0.0756 - UID_loss: 26.3742 - Stress_accuracy: 0.9728 - UID_accuracy: 0.0000e+00
# ====== Test subject: 9
# 5/5 [==============================] - 0s 2ms/step - loss: 23.1677 - Stress_loss: 0.0187 - UID_loss: 23.1490 - Stress_accuracy: 0.9932 - UID_accuracy: 0.0000e+00
# ====== Test subject: 13
# 5/5 [==============================] - 0s 2ms/step - loss: 34.1316 - Stress_loss: 0.2947 - UID_loss: 33.8369 - Stress_accuracy: 0.9128 - UID_accuracy: 0.0000e+00
# ====== Test subject: 14
# 5/5 [==============================] - 0s 1ms/step - loss: 53.8732 - Stress_loss: 1.1632 - UID_loss: 52.7101 - Stress_accuracy: 0.6913 - UID_accuracy: 0.0000e+00
# ====== Test subject: 15
# 5/5 [==============================] - 0s 1ms/step - loss: 19.5874 - Stress_loss: 0.2187 - UID_loss: 19.3687 - Stress_accuracy: 0.9597 - UID_accuracy: 0.0000e+00
# Working on dataset with Window Size = 30 seconds.
# Running AR task
# ====== Test subject: 5
# 10/10 [==============================] - 0s 1ms/step - loss: 18.7484 - Stress_loss: 0.0544 - UID_loss: 18.6940 - Stress_accuracy: 0.9797 - UID_accuracy: 0.0000e+00
# ====== Test subject: 2
# 9/9 [==============================] - 0s 1ms/step - loss: 29.0887 - Stress_loss: 0.4895 - UID_loss: 28.5992 - Stress_accuracy: 0.8728 - UID_accuracy: 0.0000e+00
# ====== Test subject: 3
# 9/9 [==============================] - 0s 1ms/step - loss: 22.9173 - Stress_loss: 1.0093 - UID_loss: 21.9080 - Stress_accuracy: 0.8467 - UID_accuracy: 0.0000e+00
# ====== Test subject: 4
# 9/9 [==============================] - 0s 1ms/step - loss: 25.4793 - Stress_loss: 0.0101 - UID_loss: 25.4692 - Stress_accuracy: 0.9931 - UID_accuracy: 0.0000e+00
# ====== Test subject: 17
# 10/10 [==============================] - 0s 1ms/step - loss: 23.3268 - Stress_loss: 0.9959 - UID_loss: 22.3309 - Stress_accuracy: 0.7483 - UID_accuracy: 0.0000e+00
# ====== Test subject: 10
# 10/10 [==============================] - 0s 1ms/step - loss: 23.9426 - Stress_loss: 0.1569 - UID_loss: 23.7857 - Stress_accuracy: 0.9408 - UID_accuracy: 0.0000e+00
# ====== Test subject: 11
# 10/10 [==============================] - 0s 1ms/step - loss: 20.9256 - Stress_loss: 0.4809 - UID_loss: 20.4447 - Stress_accuracy: 0.8658 - UID_accuracy: 0.0000e+00
# ====== Test subject: 16
# 10/10 [==============================] - 0s 1ms/step - loss: 21.1572 - Stress_loss: 0.0023 - UID_loss: 21.1549 - Stress_accuracy: 1.0000 - UID_accuracy: 0.0000e+00
# ====== Test subject: 8
# 10/10 [==============================] - 0s 1ms/step - loss: 28.6218 - Stress_loss: 0.2118 - UID_loss: 28.4100 - Stress_accuracy: 0.9051 - UID_accuracy: 0.0000e+00
# ====== Test subject: 6
# 10/10 [==============================] - 0s 1ms/step - loss: 29.1535 - Stress_loss: 0.1744 - UID_loss: 28.9791 - Stress_accuracy: 0.9422 - UID_accuracy: 0.0000e+00
# ====== Test subject: 7
# 10/10 [==============================] - 0s 1ms/step - loss: 29.7073 - Stress_loss: 0.1790 - UID_loss: 29.5282 - Stress_accuracy: 0.9422 - UID_accuracy: 0.0000e+00
# ====== Test subject: 9
# 10/10 [==============================] - 0s 1ms/step - loss: 24.8115 - Stress_loss: 0.0088 - UID_loss: 24.8027 - Stress_accuracy: 1.0000 - UID_accuracy: 0.0000e+00
# ====== Test subject: 13
# 10/10 [==============================] - 0s 1ms/step - loss: 35.6527 - Stress_loss: 0.4367 - UID_loss: 35.2160 - Stress_accuracy: 0.9128 - UID_accuracy: 0.0000e+00
# ====== Test subject: 14
# 10/10 [==============================] - 0s 1ms/step - loss: 49.1953 - Stress_loss: 1.3056 - UID_loss: 47.8898 - Stress_accuracy: 0.6296 - UID_accuracy: 0.0000e+00
# ====== Test subject: 15
# 10/10 [==============================] - 0s 1ms/step - loss: 25.5937 - Stress_loss: 0.2966 - UID_loss: 25.2971 - Stress_accuracy: 0.9396 - UID_accuracy: 0.0000e+00

# %%
mtl_60 = [[d2[-2] for d2 in data] for data in mtl_60] 
mtl_30 = [[d2[-2]for d2 in data] for data in mtl_30]

# %%
print(np.mean(ours_60,axis=1))
# Out:
# [0.92622445 0.92484191 0.92576803 0.92260759 0.92212873]

# %%
print(f'60 window | ours : {np.mean(ours_60):.4f} | {np.std(np.mean(ours_60,axis=1)):.4f}, MTL : {np.mean(mtl_60):.4f} | {np.std(np.mean(mtl_60,axis=1)):.4f}, acc_diff = {np.mean(ours_60) - np.mean(mtl_60):.4f}')
print(f'30 window | ours : {np.mean(ours_30):.4f} | {np.std(np.mean(ours_30,axis=1)):.4f}, MTL : {np.mean(mtl_30):.4f} | {np.std(np.mean(mtl_30,axis=1)):.4f}, acc_diff = {np.mean(ours_30) - np.mean(mtl_30):.4f}')
# Out:
# 60 window | ours : 0.9243 | 0.0017, MTL : 0.9211 | 0.0051, acc_diff = 0.0032
# 30 window | ours : 0.9221 | 0.0010, MTL : 0.9060 | 0.0065, acc_diff = 0.0161
